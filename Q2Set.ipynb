# %% [markdown]
# ## mYstiQ : Question Set 2
#
# **Full Marks :** 30M

# %% [markdown]
# **Q1 :** Find the sum of the following series using iterative WHILE loop.
#
# $\frac{x+5^2}{1 + 2!} + \frac{x+25^2}{2 + 3!} + ... + N$

# %% [markdown]
# **Q2:** Write a Python program using nested loops to recreate the pattern given below.

# %% [markdown]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3:You are given an integer array A. Now your task is to find the inverse of A.
#
# Now, the inverse of the array is A will be an array in which we change the
# positions of the values as their indices and indices as values.
#
# So, array A = [2, 0, 1]
# - Now 2 is at index 0. So, place 0 at index 2.
# - 0 is at index 1. So, place 1 at index 0.
# - 1 is at index 2. So, place 2 at index 1.
#
# So, the inverse of A will be [1, 2, 0]
